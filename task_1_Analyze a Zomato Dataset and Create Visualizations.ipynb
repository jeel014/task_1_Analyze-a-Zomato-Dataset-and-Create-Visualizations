# %% [markdown]
# # Analyze a Zomato Dataset and Create Visualizations

# %%
file_path = 'C:\\Users\\jeelk\\zomato.csv.csv'
zomato_data = pd.read_csv(file_path, encoding='utf-8')

# %%
import pandas as pd

# %%
zomato_data
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 56247  Four Points by Sheraton Bengaluru, 43/3, White...
# 56248  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 56249  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 56250  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 56251  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato_data_cleaned = zomato_data.dropna(subset=['name', 'location'])

# %%
zomato_data_cleaned = zomato_data.dropna(subset=['name', 'location']).copy()

zomato_data_cleaned['online_order'].fillna('No', inplace=True)
zomato_data_cleaned['book_table'].fillna('No', inplace=True)
zomato_data_cleaned['votes'].fillna('0', inplace=True)
zomato_data_cleaned['approx_cost(for two people)'].fillna('0', inplace=True)

# %%
zomato_data_cleaned['rate'] = pd.to_numeric(
    zomato_data_cleaned['rate'].str.extract(r'([\d.]+)')[0], errors='coerce'
).fillna(0).astype(float)

# %%
zomato_data_cleaned['votes'] = pd.to_numeric(zomato_data_cleaned['votes'], errors='coerce').fillna(0).astype(int)
zomato_data_cleaned['approx_cost(for two people)'] = pd.to_numeric(
    zomato_data_cleaned['approx_cost(for two people)'].str.replace(',', ''), errors='coerce'
).fillna(0).astype(float)

# %%
print(zomato_data_cleaned.info())
print(zomato_data_cleaned.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56126 entries, 0 to 56251
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      56125 non-null  object
#  1   name                         56126 non-null  object
#  2   online_order                 56126 non-null  object
#  3   book_table                   56126 non-null  object
#  4   rate                         56126 non-null  float64
#  5   votes                        56126 non-null  int32
#  6   phone                        54937 non-null  object
#  7   location                     56126 non-null  object
#  8   rest_type                    55912 non-null  object
#  9   dish_liked                   28024 non-null  object
#  10  cuisines                     56046 non-null  object
#  11  approx_cost(for two people)  56126 non-null  float64
#  12  listed_in(type)              51619 non-null  object
# ...
